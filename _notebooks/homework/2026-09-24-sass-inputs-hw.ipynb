# %% [raw]
# ---
# layout: post
# title: SASS Inputs HW
# categories: [SASS]
# lesson_language: SASS
# lesson_topic: Inputs HW
# lesson_part: interactive
# lesson_type: lesson
# codemirror: true
# permalink: /sass/inputs-hw/
# author: Aryan M
# ---

# %% [markdown]
# ## Popcorn Hack
#
# One large gradient input for searching PVO resources and one compact plain input for a volunteer's first name, both using `ocs__input`.

# %% [markdown]
# {% capture challenge1 %}
# Popcorn Hack: a large gradient search input and a small first name input. Press Run and type in the fields.
# {% endcapture %}
#
# {% capture code1 %}
# // Edit the HTML inside the quotes, then press Run.
# outputElement.innerHTML = [
#   '<p>',
#   '  <label for="pvo-resource-search">Search PVO resources</label><br>',
#   '  <input id="pvo-resource-search" type="text" class="ocs__input large gradient" placeholder="Search PVO resources...">',
#   '</p>',
#   '<p>',
#   '  <label for="popcorn-volunteer-first-name">Volunteer first name</label><br>',
#   '  <input id="popcorn-volunteer-first-name" type="text" class="ocs__input small" placeholder="Volunteer First Name">',
#   '</p>'
# ].join('');
# {% endcapture %}
#
# {% include runners/ui.html
#    runner_id="inputs-hw-popcorn"
#    challenge=challenge1
#    code=code1
#    autostart="true"
# %}

# %% [markdown]
# ## Homework Hack
#
# The PVO signup form, with a size and style modifier picked for each field:
#
# * **Assistance Category:** `ocs__input large gradient`, the main field
# * **Volunteer First Name:** `ocs__input small`, a short answer
# * **Volunteer Email:** `ocs__input medium`, a standard field with `type="email"`

# %% [markdown]
# {% capture challenge2 %}
# Homework Hack: the PVO signup form using ocs__input with size and gradient modifiers. Press Run and type in the fields.
# {% endcapture %}
#
# {% capture code2 %}
# // Edit the HTML inside the quotes, then press Run.
# outputElement.innerHTML = [
#   '<p>',
#   '  <label for="assistance-category">Assistance category</label><br>',
#   '  <input id="assistance-category" type="text" class="ocs__input large gradient" placeholder="Assistance Category">',
#   '</p>',
#   '<p>',
#   '  <label for="volunteer-first-name">Volunteer first name</label><br>',
#   '  <input id="volunteer-first-name" type="text" class="ocs__input small" placeholder="Volunteer First Name">',
#   '</p>',
#   '<p>',
#   '  <label for="volunteer-email">Volunteer email</label><br>',
#   '  <input id="volunteer-email" type="email" class="ocs__input medium" placeholder="Volunteer Email">',
#   '</p>'
# ].join('');
# {% endcapture %}
#
# {% include runners/ui.html
#    runner_id="inputs-hw-homework"
#    challenge=challenge2
#    code=code2
#    autostart="true"
# %}
